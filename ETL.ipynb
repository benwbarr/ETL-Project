# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
Rankings_file = "ETL-Project/Resources/Rankings.csv"
Rankings_df = pd.read_csv(Rankings_file)
Rankings_df.head()
# Out:
#                 Economy  Ease of Doing Business Rank  Starting a Business  \
# 0           New Zealand                            1                    1
# 1             Singapore                            2                    6
# 2               Denmark                            3                   34
# 3           Korea, Rep.                            4                    9
# 4  Hong Kong SAR, China                            5                    3
#
#    Dealing with Construction Permits  Getting Electricity  \
# 0                                  3                   37
# 1                                 16                   12
# 2                                  1                   16
# 3                                 28                    2
# 4                                  5                    4
#
#    Registering Property  Getting Credit  Protecting Minority Investors  \
# 0                     1               1                              2
# ...

# %%
GDP_file = "ETL-Project/Resources/GDP.csv"
GDP_df = pd.read_csv(GDP_file, encoding="ISO-8859-1")
GDP_df.head()
# Out:
#   Unnamed: 0  Ranking  Unnamed: 2        Economy US dollars) Unnamed: 5
# 0        USA        1         NaN  United States  21,427,700        NaN
# 1        CHN        2         NaN          China  14,342,903        NaN
# 2        JPN        3         NaN          Japan   5,081,770        NaN
# 3        DEU        4         NaN        Germany   3,845,630        NaN
# 4        IND        5         NaN          India   2,875,142        NaN

# %%
GDP_drop = GDP_df.drop(GDP_df.columns[[0,2,5]], axis = 1)
GDP_drop.head()
# Out:
#    Ranking        Economy US dollars)
# 0        1  United States  21,427,700
# 1        2          China  14,342,903
# 2        3          Japan   5,081,770
# 3        4        Germany   3,845,630
# 4        5          India   2,875,142

# %%
GDP_Names= GDP_drop.rename(columns={"Ranking": "Ranking",
                                    "Economy": "Country",
                                    "US dollars)": "GDP"})
GDP_Names.head()
# Out:
#    Ranking        Country         GDP
# 0        1  United States  21,427,700
# 1        2          China  14,342,903
# 2        3          Japan   5,081,770
# 3        4        Germany   3,845,630
# 4        5          India   2,875,142

# %%
GDP_Names.set_index("Ranking", inplace=True)
GDP_Names.head()
# Out:
#                Country         GDP
# Ranking
# 1        United States  21,427,700
# 2                China  14,342,903
# 3                Japan   5,081,770
# 4              Germany   3,845,630
# 5                India   2,875,142
