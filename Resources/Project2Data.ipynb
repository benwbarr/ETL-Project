# %%
#Importing dependencies
import pandas as pd 
import numpy as py
import os

# %%
#Reading in the data from the csv files
h_2015 = pd.read_csv('2015.csv',encoding='utf-8')

h_2016 = pd.read_csv('2016.csv',encoding='utf-8')

h_2017 = pd.read_csv('2017.csv',encoding='utf-8')

h_2018 = pd.read_csv('2018.csv',encoding='utf-8')

h_2019 = pd.read_csv('2019.csv',encoding='utf-8')

h_2020 = pd.read_csv('2020.csv',encoding='utf-8')

# %%
#putting each file into a data frame 
h_2015 = pd.DataFrame(h_2015)

h_2016 = pd.DataFrame(h_2016)

h_2017 = pd.DataFrame(h_2017)

h_2018 = pd.DataFrame(h_2018)

h_2019 = pd.DataFrame(h_2019)

h_2020 = pd.DataFrame(h_2020)

# %%
#Creating a Column year, that will correspond to each dataset 
h_2015['Year'] = "2015"

h_2016['Year'] = "2016"

h_2017['Year'] = "2017"

h_2018['Year'] = "2018"

h_2019['Year'] = "2019"

h_2020['Year'] = "2020"

# %%
h_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
print(h_2015.columns)
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Year'],
#       dtype='object')

# %%
#Rounding all values in the columns to 4 digits

h_2015['Happiness Score'] = round(h_2015['Happiness Score'],4)

h_2015['Economy (GDP per Capita)'] = round(h_2015['Economy (GDP per Capita)'],4)

h_2015['Family'] = round(h_2015['Family'],4)

h_2015['Health (Life Expectancy)'] = round(h_2015['Health (Life Expectancy)'],4)

h_2015['Freedom'] = round(h_2015['Freedom'],4)

h_2015['Trust (Government Corruption)'] = round(h_2015['Trust (Government Corruption)'],4)

h_2015['Generosity'] = round(h_2015['Generosity'],4)

h_2015['Dystopia Residual'] = round(h_2015['Dystopia Residual'],4)

h_2015['Standard Error'] = round(h_2015['Standard Error'],4)

# %%
h_2015 = h_2015.rename(columns={'Happiness Rank':'Happiness_Rank_2015',
                                   'Happiness Score':'Happiness_Score_2015',
                                    'Economy (GDP per Capita)':'Economy(GDP per Capita)_2015', 'Family':'Family_2015',
                                   'Health (Life Expectancy)':'Health_(Life_Expectancy)_2015', 'Freedom':'Freedom_2015',
                                   'Trust (Government Corruption)':'Trust(Government_Corruption)_2015', 'Generosity':'Generosity_2015',
                                   'Dystopia Residual':'Dystopia_Residual_2015'})

# %%
h_2015.drop(['Year'], axis=1, inplace=True)

h_2015
# Out:
#          Country                           Region  Happiness_Rank_2015  \
# 0    Switzerland                   Western Europe                    1
# 1        Iceland                   Western Europe                    2
# 2        Denmark                   Western Europe                    3
# 3         Norway                   Western Europe                    4
# 4         Canada                    North America                    5
# ..           ...                              ...                  ...
# 153       Rwanda               Sub-Saharan Africa                  154
# 154        Benin               Sub-Saharan Africa                  155
# 155        Syria  Middle East and Northern Africa                  156
# 156      Burundi               Sub-Saharan Africa                  157
# 157         Togo               Sub-Saharan Africa                  158
#
#      Happiness_Score_2015  Standard Error  Economy(GDP per Capita)_2015  \
# ...

# %%
h_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
#Rounding all values in the columns to 4 digits

h_2016['Happiness Score'] = round(h_2016['Happiness Score'],4)

h_2016['Lower Confidence Interval'] = round(h_2016['Lower Confidence Interval'],4)

h_2016['Upper Confidence Interval'] = round(h_2016['Upper Confidence Interval'],4)

h_2016['Economy (GDP per Capita)'] = round(h_2016['Economy (GDP per Capita)'],4)

h_2016['Family'] = round(h_2016['Family'],4)

h_2016['Health (Life Expectancy)'] = round(h_2016['Health (Life Expectancy)'],4)

h_2016['Freedom'] = round(h_2016['Freedom'],4)

h_2016['Trust (Government Corruption)'] = round(h_2016['Trust (Government Corruption)'],4)

h_2016['Generosity'] = round(h_2016['Generosity'],4)

h_2016['Dystopia Residual'] = round(h_2016['Dystopia Residual'],4)

# %%
print(h_2016.columns)
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual', 'Year'],
#       dtype='object')

# %%
h_2016 = h_2016.rename(columns={'Happiness Rank':'Happiness_Rank_2016',
                                   'Happiness Score':'Happiness_Score_2016',
                                    'Economy (GDP per Capita)':'Economy(GDP per Capita)_2016', 'Family':'Family_2016',
                                   'Health (Life Expectancy)':'Health_(Life_Expectancy)_2016', 'Freedom':'Freedom_2016',
                                   'Trust (Government Corruption)':'Trust(Government_Corruption)_2016', 'Generosity':'Generosity_2016',
                                   'Dystopia Residual':'Dystopia_Residual_2016'})

# %%
h_2016.drop(['Region', 'Year','Lower Confidence Interval','Upper Confidence Interval'], axis=1, inplace=True)

h_2016
# Out:
#          Country  Happiness_Rank_2016  Happiness_Score_2016  \
# 0        Denmark                    1                 7.526
# 1    Switzerland                    2                 7.509
# 2        Iceland                    3                 7.501
# 3         Norway                    4                 7.498
# 4        Finland                    5                 7.413
# ..           ...                  ...                   ...
# 152        Benin                  153                 3.484
# 153  Afghanistan                  154                 3.360
# 154         Togo                  155                 3.303
# 155        Syria                  156                 3.069
# 156      Burundi                  157                 2.905
#
#      Economy(GDP per Capita)_2016  Family_2016  Health_(Life_Expectancy)_2016  \
# 0                          1.4418       1.1637                         0.7950
# 1                          1.5273       1.1452                         0.8630
# ...

# %%
h_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
print(h_2017.columns)
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual', 'Year'],
#       dtype='object')

# %%
h_2017['Happiness.Score'] = round(h_2017['Happiness.Score'],4)

h_2017['Whisker.low'] = round(h_2017['Whisker.low'],4)

h_2017['Whisker.high'] = round(h_2017['Whisker.high'],4)

h_2017['Economy..GDP.per.Capita.'] = round(h_2017['Economy..GDP.per.Capita.'],4)

h_2017['Family'] = round(h_2017['Family'],4)

h_2017['Health..Life.Expectancy.'] = round(h_2017['Health..Life.Expectancy.'],4)

h_2017['Freedom'] = round(h_2017['Freedom'],4)

h_2017['Trust..Government.Corruption.'] = round(h_2017['Trust..Government.Corruption.'],4)

h_2017['Generosity'] = round(h_2017['Generosity'],4)

h_2017['Dystopia.Residual'] = round(h_2017['Dystopia.Residual'],4)

# %%
print(h_2017.columns)
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual', 'Year'],
#       dtype='object')

# %%
h_2017 = h_2017.rename(columns={'Happiness.Rank':'Happiness_Rank_2017',
'Happiness.Score':'Happiness_Score_2017',
'Economy..GDP.per.Capita.':'Economy(GDP_per_Capita)_2017', 'Family':'Family_2017',
'Health..Life.Expectancy.':'Health_(Life Expectancy)_2017', 'Freedom':'Freedom_2017',
'Trust..Government.Corruption.':'Trust_(Government_Corruption)_2017','Generosity':'Generosity_2017',
'Dystopia.Residual':'Dystopia_Residual_2017'})

h_2017
# Out:
#                       Country  Happiness_Rank_2017  Happiness_Score_2017  \
# 0                      Norway                    1                 7.537
# 1                     Denmark                    2                 7.522
# 2                     Iceland                    3                 7.504
# 3                 Switzerland                    4                 7.494
# 4                     Finland                    5                 7.469
# ..                        ...                  ...                   ...
# 150                    Rwanda                  151                 3.471
# 151                     Syria                  152                 3.462
# 152                  Tanzania                  153                 3.349
# 153                   Burundi                  154                 2.905
# 154  Central African Republic                  155                 2.693
#
#      Whisker.high  Whisker.low  Economy(GDP_per_Capita)_2017  Family_2017  \
# ...

# %%
h_2017.drop(['Year','Whisker.low','Whisker.high'], axis=1, inplace=True)

h_2017
# Out:
#                       Country  Happiness_Rank_2017  Happiness_Score_2017  \
# 0                      Norway                    1                 7.537
# 1                     Denmark                    2                 7.522
# 2                     Iceland                    3                 7.504
# 3                 Switzerland                    4                 7.494
# 4                     Finland                    5                 7.469
# ..                        ...                  ...                   ...
# 150                    Rwanda                  151                 3.471
# 151                     Syria                  152                 3.462
# 152                  Tanzania                  153                 3.349
# 153                   Burundi                  154                 2.905
# 154  Central African Republic                  155                 2.693
#
#      Economy(GDP_per_Capita)_2017  Family_2017  Health_(Life Expectancy)_2017  \
# ...

# %%
h_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
#  9   Year                          156 non-null    object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 12.3+ KB

# %%
print(h_2018.columns)
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Year'],
#       dtype='object')

# %%
h_2018['Overall rank'] = round(h_2018['Overall rank'],4)

h_2018['Score'] = round(h_2018['Overall rank'],4)

h_2018['GDP per capita'] = round(h_2018['GDP per capita'],4)

h_2018['Social support'] = round(h_2018['Social support'],4)

h_2018['Healthy life expectancy'] = round(h_2018['Healthy life expectancy'],4)

h_2018['Freedom to make life choices'] = round(h_2018['Freedom to make life choices'],4)

h_2018['Perceptions of corruption'] = round(h_2018['Perceptions of corruption'],4)

h_2018['Generosity'] = round(h_2018['Generosity'],4)

# %%
print(h_2018.columns)
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Year'],
#       dtype='object')

# %%
h_2018 = h_2018.rename(columns={'Country or region':'Country','Overall rank':'Happiness Rank_2018',
'Score':'Happiness_Score_2018','GDP per capita':'Economy(GDP_per_Capita)_2018', 'Social support':'Family_2018',
'Healthy life expectancy':'Health_(Life Expectancy)_2018', 'Freedom to make life choices':'Freedom_2018',
'Perceptions of corruption':'Trust_(Government_Corruption)_2018', 'Generosity':'Generosity_2018'})

h_2018
# Out:
#      Happiness Rank_2018                   Country  Happiness_Score_2018  \
# 0                      1                   Finland                 7.632
# 1                      2                    Norway                 7.594
# 2                      3                   Denmark                 7.555
# 3                      4                   Iceland                 7.495
# 4                      5               Switzerland                 7.487
# ..                   ...                       ...                   ...
# 151                  152                     Yemen                 3.355
# 152                  153                  Tanzania                 3.303
# 153                  154               South Sudan                 3.254
# 154                  155  Central African Republic                 3.083
# 155                  156                   Burundi                 2.905
#
#      Economy(GDP_per_Capita)_2018  Family_2018  Health_(Life Expectancy)_2018  \
# ...

# %%
h_2018.drop(['Year'], axis=1, inplace=True)

# %%
h_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
#  9   Year                          156 non-null    object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 12.3+ KB

# %%
print(h_2019.columns)
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Year'],
#       dtype='object')

# %%
h_2019['Overall rank'] = round(h_2019['Overall rank'],4)

h_2019['Score'] = round(h_2019['Score'],4)

h_2019['Social support'] = round(h_2019['Social support'],4)

h_2019['Healthy life expectancy'] = round(h_2019['Healthy life expectancy'],4)

h_2019['Freedom to make life choices'] = round(h_2019['Freedom to make life choices'],4)

h_2019['Perceptions of corruption'] = round(h_2019['Perceptions of corruption'],4)

h_2019['Generosity'] = round(h_2019['Generosity'],4)

# %%
h_2019 = h_2019.rename(columns={'Country or region':'Country','Overall rank':'Happiness Rank_2019',
'Score':'Happiness_Score_2019','GDP per capita':'Economy(GDP_per_Capita)_2019', 'Social support':'Family_2019',
'Healthy life expectancy':'Health_(Life Expectancy)_2019', 'Freedom to make life choices':'Freedom_2019',
'Perceptions of corruption':'Trust_(Government_Corruption)_2019', 'Generosity':'Generosity_2019'})

h_2019
# Out:
#      Happiness Rank_2019                   Country  Happiness_Score_2019  \
# 0                      1                   Finland                 7.769
# 1                      2                   Denmark                 7.600
# 2                      3                    Norway                 7.554
# 3                      4                   Iceland                 7.494
# 4                      5               Netherlands                 7.488
# ..                   ...                       ...                   ...
# 151                  152                    Rwanda                 3.334
# 152                  153                  Tanzania                 3.231
# 153                  154               Afghanistan                 3.203
# 154                  155  Central African Republic                 3.083
# 155                  156               South Sudan                 2.853
#
#      Economy(GDP_per_Capita)_2019  Family_2019  Health_(Life Expectancy)_2019  \
# ...

# %%
h_2019.drop(['Year'], axis=1, inplace=True)


h_2019
# Out:
#      Happiness Rank_2019                   Country  Happiness_Score_2019  \
# 0                      1                   Finland                 7.769
# 1                      2                   Denmark                 7.600
# 2                      3                    Norway                 7.554
# 3                      4                   Iceland                 7.494
# 4                      5               Netherlands                 7.488
# ..                   ...                       ...                   ...
# 151                  152                    Rwanda                 3.334
# 152                  153                  Tanzania                 3.231
# 153                  154               Afghanistan                 3.203
# 154                  155  Central African Republic                 3.083
# 155                  156               South Sudan                 2.853
#
#      Economy(GDP_per_Capita)_2019  Family_2019  Health_(Life Expectancy)_2019  \
# ...

# %%
h_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 21 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                153 non-null    object
#  1   Regional indicator                          153 non-null    object
#  2   Ladder score                                153 non-null    float64
#  3   Standard error of ladder score              153 non-null    float64
#  4   upperwhisker                                153 non-null    float64
#  5   lowerwhisker                                153 non-null    float64
#  6   Logged GDP per capita                       153 non-null    float64
#  7   Social support                              153 non-null    float64
#  8   Healthy life expectancy                     153 non-null    float64
# ...

# %%
print(h_2020.columns)
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual', 'Year'],
#       dtype='object')

# %%
h_2020['Ladder score'] = round(h_2020['Ladder score'],4)

h_2020['Standard error of ladder score'] = round(h_2020['Standard error of ladder score'],4)

h_2020['Logged GDP per capita'] = round(h_2020['Logged GDP per capita'],4)

h_2020['Social support'] = round(h_2020['Social support'],4)

h_2020['Healthy life expectancy'] = round(h_2020['Healthy life expectancy'],4)

h_2020['Freedom to make life choices'] = round(h_2020['Freedom to make life choices'],4)

h_2020['Perceptions of corruption'] = round(h_2020['Perceptions of corruption'],4)

h_2020['Generosity'] = round(h_2020['Generosity'],4)

h_2020['Ladder score in Dystopia'] = round(h_2020['Ladder score in Dystopia'],4)

# %%
h_2020 = h_2020.rename(columns={'Country name':'Country','Happiness Rank':'Happiness Rank_2020',
'Ladder score':'Happiness_Score_2020','Logged GDP per capita':'Economy(GDP_per_Capita)_2020', 'Social support':'Family_2020',
'Healthy life expectancy':'Health_(Life Expectancy)_2020', 'Freedom to make life choices':'Freedom_2020',
'Perceptions of corruption':'Trust_(Government_Corruption)_2020', 'Generosity':'Generosity_2020',
'Ladder score in Dystopia':'Dystopia_Residual_2020'})

h_2020
# Out:
#                       Country  Regional indicator  Happiness_Score_2020  \
# 0                     Finland      Western Europe                7.8087
# 1                     Denmark      Western Europe                7.6456
# 2                 Switzerland      Western Europe                7.5599
# 3                     Iceland      Western Europe                7.5045
# 4                      Norway      Western Europe                7.4880
# ..                        ...                 ...                   ...
# 148  Central African Republic  Sub-Saharan Africa                3.4759
# 149                    Rwanda  Sub-Saharan Africa                3.3123
# 150                  Zimbabwe  Sub-Saharan Africa                3.2992
# 151               South Sudan  Sub-Saharan Africa                2.8166
# 152               Afghanistan          South Asia                2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# ...

# %%
h_2020.drop(['Regional indicator','Standard error of ladder score','upperwhisker', 'lowerwhisker','Explained by: Log GDP per capita', 'Explained by: Social support',
       'Explained by: Healthy life expectancy',
       'Explained by: Freedom to make life choices',
       'Explained by: Generosity', 'Explained by: Perceptions of corruption',
       'Dystopia + residual', 'Year'], axis=1, inplace=True)


h_2020
# Out:
#                       Country  Happiness_Score_2020  \
# 0                     Finland                7.8087
# 1                     Denmark                7.6456
# 2                 Switzerland                7.5599
# 3                     Iceland                7.5045
# 4                      Norway                7.4880
# ..                        ...                   ...
# 148  Central African Republic                3.4759
# 149                    Rwanda                3.3123
# 150                  Zimbabwe                3.2992
# 151               South Sudan                2.8166
# 152               Afghanistan                2.5669
#
#      Economy(GDP_per_Capita)_2020  Family_2020  Health_(Life Expectancy)_2020  \
# 0                         10.6393       0.9543                        71.9008
# 1                         10.7740       0.9560                        72.4025
# 2                         10.9799       0.9428                        74.1024
# ...

# %%
first_df = pd.merge(h_2015,h_2016, on=['Country'])

second_df = pd.merge(first_df,h_2017, on=['Country'])

third_df = pd.merge(second_df, h_2018, on=['Country'])

fourth_df = pd.merge(third_df, h_2019, on=['Country'])

fifth_df = pd.merge(fourth_df, h_2020, on=['Country'])


fifth_df = pd.DataFrame(fifth_df)

fifth_df
# Out:
#          Country              Region  Happiness_Rank_2015  \
# 0    Switzerland      Western Europe                    1
# 1        Iceland      Western Europe                    2
# 2        Denmark      Western Europe                    3
# 3         Norway      Western Europe                    4
# 4         Canada       North America                    5
# ..           ...                 ...                  ...
# 133  Afghanistan       Southern Asia                  153
# 134       Rwanda  Sub-Saharan Africa                  154
# 135        Benin  Sub-Saharan Africa                  155
# 136      Burundi  Sub-Saharan Africa                  157
# 137         Togo  Sub-Saharan Africa                  158
#
#      Happiness_Score_2015  Standard Error  Economy(GDP per Capita)_2015  \
# 0                   7.587          0.0341                        1.3965
# 1                   7.561          0.0488                        1.3023
# ...

# %%
fifth_df.drop(['Region','Standard Error'],axis=1,inplace=True)

# %%
fifth_df
# Out:
#          Country  Happiness_Rank_2015  Happiness_Score_2015  \
# 0    Switzerland                    1                 7.587
# 1        Iceland                    2                 7.561
# 2        Denmark                    3                 7.527
# 3         Norway                    4                 7.522
# 4         Canada                    5                 7.427
# ..           ...                  ...                   ...
# 133  Afghanistan                  153                 3.575
# 134       Rwanda                  154                 3.465
# 135        Benin                  155                 3.340
# 136      Burundi                  157                 2.905
# 137         Togo                  158                 2.839
#
#      Economy(GDP per Capita)_2015  Family_2015  Health_(Life_Expectancy)_2015  \
# 0                          1.3965       1.3495                         0.9414
# 1                          1.3023       1.4022                         0.9478
# ...

# %%
economy_df = fifth_df[['Country','Economy(GDP per Capita)_2015','Economy(GDP per Capita)_2016',
                      'Economy(GDP_per_Capita)_2017','Economy(GDP_per_Capita)_2018','Economy(GDP_per_Capita)_2019',
                      'Economy(GDP_per_Capita)_2020']]

economy_df = pd.DataFrame(economy_df)

economy_df = economy_df.set_index('Country')

economy_df
# Out:
#              Economy(GDP per Capita)_2015  Economy(GDP per Capita)_2016  \
# Country
# Switzerland                        1.3965                        1.5273
# Iceland                            1.3023                        1.4267
# Denmark                            1.3255                        1.4418
# Norway                             1.4590                        1.5774
# Canada                             1.3263                        1.4402
# ...                                   ...                           ...
# Afghanistan                        0.3198                        0.3823
# Rwanda                             0.2221                        0.3285
# Benin                              0.2866                        0.3950
# Burundi                            0.0153                        0.0683
# Togo                               0.2087                        0.2812
#
#              Economy(GDP_per_Capita)_2017  Economy(GDP_per_Capita)_2018  \
# Country
# ...

# %%
life_df = fifth_df[['Country', 'Happiness_Rank_2015',
       'Happiness_Score_2015', 'Family_2015',
       'Health_(Life_Expectancy)_2015', 'Freedom_2015',
       'Trust(Government_Corruption)_2015', 'Generosity_2015',
       'Dystopia_Residual_2015', 'Happiness_Rank_2016', 'Happiness_Score_2016','Family_2016',
       'Health_(Life_Expectancy)_2016', 'Freedom_2016',
       'Trust(Government_Corruption)_2016', 'Generosity_2016',
       'Dystopia_Residual_2016', 'Happiness_Rank_2017', 'Happiness_Score_2017','Family_2017',
       'Health_(Life Expectancy)_2017', 'Freedom_2017', 'Generosity_2017',
       'Trust_(Government_Corruption)_2017', 'Dystopia_Residual_2017',
       'Happiness Rank_2018', 'Happiness_Score_2018',
       'Family_2018','Health_(Life Expectancy)_2018', 'Freedom_2018', 'Generosity_2018',
       'Trust_(Government_Corruption)_2018', 'Happiness Rank_2019',
       'Happiness_Score_2019','Family_2019',
       'Health_(Life Expectancy)_2019', 'Freedom_2019', 'Generosity_2019',
       'Trust_(Government_Corruption)_2019', 'Happiness_Score_2020',
       'Family_2020',
       'Health_(Life Expectancy)_2020', 'Freedom_2020', 'Generosity_2020',
       'Trust_(Government_Corruption)_2020', 'Dystopia_Residual_2020']]

life_df = pd.DataFrame(life_df)

life_df = life_df.set_index('Country')

life_df
# Out:
#              Happiness_Rank_2015  Happiness_Score_2015  Family_2015  \
# Country
# Switzerland                    1                 7.587       1.3495
# Iceland                        2                 7.561       1.4022
# Denmark                        3                 7.527       1.3606
# Norway                         4                 7.522       1.3310
# Canada                         5                 7.427       1.3226
# ...                          ...                   ...          ...
# Afghanistan                  153                 3.575       0.3028
# Rwanda                       154                 3.465       0.7737
# Benin                        155                 3.340       0.3539
# Burundi                      157                 2.905       0.4159
# Togo                         158                 2.839       0.1400
#
#              Health_(Life_Expectancy)_2015  Freedom_2015  \
# Country
# Switzerland                         0.9414        0.6656
# ...

# %%
economy_df.to_csv('economy_rankings.csv')

life_df.to_csv('life_rankings.csv')
