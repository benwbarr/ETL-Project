# %%
#Importing dependencies
import pandas as pd 
import numpy as py
import os

# %%
#Reading in the data from the csv files
h_2015 = pd.read_csv('Project2/2015.csv',encoding='utf-8')

h_2016 = pd.read_csv('Project2/2016.csv',encoding='utf-8')

h_2017 = pd.read_csv('Project2/2016.csv',encoding='utf-8')

h_2018 = pd.read_csv('Project2/2016.csv',encoding='utf-8')

h_2019 = pd.read_csv('Project2/2016.csv',encoding='utf-8')

h_2020 = pd.read_csv('Project2/2016.csv',encoding='utf-8')

# %%
#observing the data types that are in the data set 
h_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
#putting each file into a data frame 
h_2015 = pd.DataFrame(h_2015)

h_2016 = pd.DataFrame(h_2016)

h_2017 = pd.DataFrame(h_2017)

h_2018 = pd.DataFrame(h_2018)

h_2019 = pd.DataFrame(h_2019)

h_2020 = pd.DataFrame(h_2020)

# %%
#Creating a Column year, that will correspond to each dataset 
h_2015['Year'] = "2015"

h_2016['Year'] = "2016"

h_2017['Year'] = "2017"

h_2018['Year'] = "2018"

h_2019['Year'] = "2019"

h_2020['Year'] = "2020"

# %%
print(h_2015.columns)
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Year'],
#       dtype='object')

# %%
#Rounding all values in the columns to 4 digits

h_2015['Happiness Score'] = round(h_2015['Happiness Score'],4)

h_2015['Economy (GDP per Capita)'] = round(h_2015['Economy (GDP per Capita)'],4)

h_2015['Family'] = round(h_2015['Family'],4)

h_2015['Health (Life Expectancy)'] = round(h_2015['Health (Life Expectancy)'],4)

h_2015['Freedom'] = round(h_2015['Freedom'],4)

h_2015['Trust (Government Corruption)'] = round(h_2015['Trust (Government Corruption)'],4)

h_2015['Generosity'] = round(h_2015['Generosity'],4)

h_2015['Dystopia Residual'] = round(h_2015['Dystopia Residual'],4)

h_2015['Standard Error'] = round(h_2015['Standard Error'],4)

# %%
#Rounding all values in the columns to 4 digits

h_2016['Happiness Score'] = round(h_2016['Happiness Score'],4)

h_2016['Lower Confidence Interval'] = round(h_2016['Lower Confidence Interval'],4)

h_2016['Upper Confidence Interval'] = round(h_2016['Upper Confidence Interval'],4)

h_2016['Economy (GDP per Capita)'] = round(h_2016['Economy (GDP per Capita)'],4)

h_2016['Family'] = round(h_2016['Family'],4)

h_2016['Health (Life Expectancy)'] = round(h_2016['Health (Life Expectancy)'],4)

h_2016['Freedom'] = round(h_2016['Freedom'],4)

h_2016['Trust (Government Corruption)'] = round(h_2016['Trust (Government Corruption)'],4)

h_2016['Generosity'] = round(h_2016['Generosity'],4)

h_2016['Dystopia Residual'] = round(h_2016['Dystopia Residual'],4)

# %%
h_2017['Happiness Score'] = round(h_2017['Happiness Score'],4)

h_2017['Lower Confidence Interval'] = round(h_2017['Lower Confidence Interval'],4)

h_2017['Upper Confidence Interval'] = round(h_2017['Upper Confidence Interval'],4)

h_2017['Economy (GDP per Capita)'] = round(h_2017['Economy (GDP per Capita)'],4)

h_2017['Family'] = round(h_2017['Family'],4)

h_2017['Health (Life Expectancy)'] = round(h_2017['Health (Life Expectancy)'],4)

h_2017['Freedom'] = round(h_2017['Freedom'],4)

h_2017['Trust (Government Corruption)'] = round(h_2017['Trust (Government Corruption)'],4)

h_2017['Generosity'] = round(h_2017['Generosity'],4)

h_2017['Dystopia Residual'] = round(h_2017['Dystopia Residual'],4)

# %%
h_2018['Happiness Score'] = round(h_2018['Happiness Score'],4)

h_2018['Lower Confidence Interval'] = round(h_2018['Lower Confidence Interval'],4)

h_2018['Upper Confidence Interval'] = round(h_2018['Upper Confidence Interval'],4)

h_2018['Economy (GDP per Capita)'] = round(h_2018['Economy (GDP per Capita)'],4)

h_2018['Family'] = round(h_2018['Family'],4)

h_2018['Health (Life Expectancy)'] = round(h_2018['Health (Life Expectancy)'],4)

h_2018['Freedom'] = round(h_2018['Freedom'],4)

h_2018['Trust (Government Corruption)'] = round(h_2018['Trust (Government Corruption)'],4)

h_2018['Generosity'] = round(h_2018['Generosity'],4)

h_2018['Dystopia Residual'] = round(h_2018['Dystopia Residual'],4)

# %%
h_2019['Happiness Score'] = round(h_2019['Happiness Score'],4)

h_2019['Lower Confidence Interval'] = round(h_2019['Lower Confidence Interval'],4)

h_2019['Upper Confidence Interval'] = round(h_2019['Upper Confidence Interval'],4)

h_2019['Economy (GDP per Capita)'] = round(h_2019['Economy (GDP per Capita)'],4)

h_2019['Family'] = round(h_2019['Family'],4)

h_2019['Health (Life Expectancy)'] = round(h_2019['Health (Life Expectancy)'],4)

h_2019['Freedom'] = round(h_2019['Freedom'],4)

h_2019['Trust (Government Corruption)'] = round(h_2019['Trust (Government Corruption)'],4)

h_2019['Generosity'] = round(h_2019['Generosity'],4)

h_2019['Dystopia Residual'] = round(h_2019['Dystopia Residual'],4)

# %%
h_2020['Happiness Score'] = round(h_2020['Happiness Score'],4)

h_2020['Lower Confidence Interval'] = round(h_2020['Lower Confidence Interval'],4)

h_2020['Upper Confidence Interval'] = round(h_2020['Upper Confidence Interval'],4)

h_2020['Economy (GDP per Capita)'] = round(h_2020['Economy (GDP per Capita)'],4)

h_2020['Family'] = round(h_2020['Family'],4)

h_2020['Health (Life Expectancy)'] = round(h_2020['Health (Life Expectancy)'],4)

h_2020['Freedom'] = round(h_2020['Freedom'],4)

h_2020['Trust (Government Corruption)'] = round(h_2020['Trust (Government Corruption)'],4)

h_2020['Generosity'] = round(h_2020['Generosity'],4)

h_2020['Dystopia Residual'] = round(h_2020['Dystopia Residual'],4)

# %%
h_2017
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
h_2018
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
h_2019
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
h_2020
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
first_df = pd.merge(h_2015,h_2016, on=['Country'])

second_df = pd.merge(first_df,h_2017, on=['Country'])

third_df = pd.merge(second_df, h_2018, on=['Country'])

fourth_df = pd.merge(third_df, h_2019, on=['Country'])

fifth_df = pd.merge(fourth_df, h_2020, on=['Country'])

# %%
fifth_df.to_csv('Project2/final.csv')
