# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
Rankings_file = "Resources/Rankings.csv"
Rankings_df = pd.read_csv(Rankings_file)
Rankings_df.head()
# Out:
#                 Economy  Ease of Doing Business Rank  Starting a Business  \
# 0           New Zealand                            1                    1
# 1             Singapore                            2                    6
# 2               Denmark                            3                   34
# 3           Korea, Rep.                            4                    9
# 4  Hong Kong SAR, China                            5                    3
#
#    Dealing with Construction Permits  Getting Electricity  \
# 0                                  3                   37
# 1                                 16                   12
# 2                                  1                   16
# 3                                 28                    2
# 4                                  5                    4
#
#    Registering Property  Getting Credit  Protecting Minority Investors  \
# 0                     1               1                              2
# ...

# %%
GDP_file = "Resources/GDP.csv"
GDP_df = pd.read_csv(GDP_file, encoding="ISO-8859-1")
GDP_df.head()
# Out:
#   Unnamed: 0  Ranking  Unnamed: 2        Economy US dollars) Unnamed: 5
# 0        USA        1         NaN  United States  21,427,700        NaN
# 1        CHN        2         NaN          China  14,342,903        NaN
# 2        JPN        3         NaN          Japan   5,081,770        NaN
# 3        DEU        4         NaN        Germany   3,845,630        NaN
# 4        IND        5         NaN          India   2,875,142        NaN

# %%
Growth_file = "Resources/Growth.csv"
Growth_df = pd.read_csv(Growth_file)
Growth_df.head()
# Out:
#       Country  Population Rank Growth Rate World Percentage  Density  \
# 0       Japan             11.0      -0.30%            1.62%   334.66
# 1  Mauritania            127.0       2.74%            0.06%     4.51
# 2  Cape Verde            172.0       1.10%            0.01%   137.86
# 3     Tunisia             79.0       1.06%            0.15%    72.24
# 4     Eritrea            133.0       1.41%            0.05%    30.16
#
#    Land Area  2020 Population Rank 2020 World Percentage 2020 Growth Rate  \
# 0    364,555                    11                 1.62%           -0.30%
# 1  1,030,700                   127                 0.06%            2.74%
# 2      4,030                   172                 0.01%            1.10%
# 3    155,360                    79                 0.15%            1.06%
# 4    101,000                   133                 0.05%            1.41%
#
#         Area Capital City  Region        Subregion Anthem Government  \
# ...

# %%
Health_file = "Resources/Health.csv"
Health_df = pd.read_csv(Health_file)
Health_df.head()
# Out:
#    Rank      Country  Health_Care_Index
# 0     1       Taiwan              86.71
# 1     2  South Korea              81.97
# 2     3        Japan              81.14
# 3     4      Denmark              80.00
# 4     5       France              79.99

# %%
Final_file = "Resources/final.csv"
Final_Merge = pd.read_csv(Final_file)
Final_Merge.head()
# Out:
#    Unnamed: 0      Country        Region_x  Happiness Rank_x  \
# 0           0  Switzerland  Western Europe                 1
# 1           1      Iceland  Western Europe                 2
# 2           2      Denmark  Western Europe                 3
# 3           3       Norway  Western Europe                 4
# 4           4       Canada   North America                 5
#
#    Happiness Score_x  Standard Error  Economy (GDP per Capita)_x  Family_x  \
# 0              7.587          0.0341                      1.3965    1.3495
# 1              7.561          0.0488                      1.3023    1.4022
# 2              7.527          0.0333                      1.3255    1.3606
# 3              7.522          0.0388                      1.4590    1.3310
# 4              7.427          0.0355                      1.3263    1.3226
#
#    Health (Life Expectancy)_x  Freedom_x  ...  Lower Confidence Interval  \
# ...

# %%
GDP_drop = GDP_df.drop(GDP_df.columns[[0,2,5]], axis = 1)
GDP_drop.head()
# Out:
#    Ranking        Economy US dollars)
# 0        1  United States  21,427,700
# 1        2          China  14,342,903
# 2        3          Japan   5,081,770
# 3        4        Germany   3,845,630
# 4        5          India   2,875,142

# %%
GDP_final= GDP_drop.rename(columns={"Ranking": "GDP Ranking",
                                    "Economy": "Country",
                                    "US dollars)": "GDP"})
GDP_final.head()
# Out:
#    GDP Ranking        Country         GDP
# 0            1  United States  21,427,700
# 1            2          China  14,342,903
# 2            3          Japan   5,081,770
# 3            4        Germany   3,845,630
# 4            5          India   2,875,142

# %%
GDP_final.set_index("Country", inplace=True)
GDP_final.head()
# Out:
#                GDP Ranking         GDP
# Country
# United States            1  21,427,700
# China                    2  14,342,903
# Japan                    3   5,081,770
# Germany                  4   3,845,630
# India                    5   2,875,142

# %%
Rankings_final = Rankings_df.rename(columns = {"Economy": "Country"})
Rankings_final.head()
# Out:
#                 Country  Ease of Doing Business Rank  Starting a Business  \
# 0           New Zealand                            1                    1
# 1             Singapore                            2                    6
# 2               Denmark                            3                   34
# 3           Korea, Rep.                            4                    9
# 4  Hong Kong SAR, China                            5                    3
#
#    Dealing with Construction Permits  Getting Electricity  \
# 0                                  3                   37
# 1                                 16                   12
# 2                                  1                   16
# 3                                 28                    2
# 4                                  5                    4
#
#    Registering Property  Getting Credit  Protecting Minority Investors  \
# 0                     1               1                              2
# ...

# %%
Rankings_final.set_index("Country", inplace=True)
Rankings_final.head()
# Out:
#                       Ease of Doing Business Rank  Starting a Business  \
# Country
# New Zealand                                     1                    1
# Singapore                                       2                    6
# Denmark                                         3                   34
# Korea, Rep.                                     4                    9
# Hong Kong SAR, China                            5                    3
#
#                       Dealing with Construction Permits  Getting Electricity  \
# Country
# New Zealand                                           3                   37
# Singapore                                            16                   12
# Denmark                                               1                   16
# Korea, Rep.                                          28                    2
# Hong Kong SAR, China                                  5                    4
#
# ...

# %%
Growth_drop = Growth_df.drop(Growth_df.columns[[4,6,7,8,9,11,12,13,14,15,16,17]], axis = 1)
Growth_drop.head()
# Out:
#       Country  Population Rank Growth Rate World Percentage  Land Area  \
# 0       Japan             11.0      -0.30%            1.62%    364,555
# 1  Mauritania            127.0       2.74%            0.06%  1,030,700
# 2  Cape Verde            172.0       1.10%            0.01%      4,030
# 3     Tunisia             79.0       1.06%            0.15%    155,360
# 4     Eritrea            133.0       1.41%            0.05%    101,000
#
#   Capital City
# 0        Tokyo
# 1   Nouakchott
# 2        Praia
# 3        Tunis
# 4       Asmara

# %%
Growth_final = Growth_drop.rename(columns = {"Country": "Country",
                                             "World Percentage": "World Percentage of Population",})
                                             
Growth_final.head()
# Out:
#       Country  Population Rank Growth Rate World Percentage of Population  \
# 0       Japan             11.0      -0.30%                          1.62%
# 1  Mauritania            127.0       2.74%                          0.06%
# 2  Cape Verde            172.0       1.10%                          0.01%
# 3     Tunisia             79.0       1.06%                          0.15%
# 4     Eritrea            133.0       1.41%                          0.05%
#
#    Land Area Capital City
# 0    364,555        Tokyo
# 1  1,030,700   Nouakchott
# 2      4,030        Praia
# 3    155,360        Tunis
# 4    101,000       Asmara

# %%
Growth_final.set_index("Country", inplace=True)
Growth_final.head()
# Out:
#             Population Rank Growth Rate World Percentage of Population  \
# Country
# Japan                  11.0      -0.30%                          1.62%
# Mauritania            127.0       2.74%                          0.06%
# Cape Verde            172.0       1.10%                          0.01%
# Tunisia                79.0       1.06%                          0.15%
# Eritrea               133.0       1.41%                          0.05%
#
#             Land Area Capital City
# Country
# Japan         364,555        Tokyo
# Mauritania  1,030,700   Nouakchott
# Cape Verde      4,030        Praia
# Tunisia       155,360        Tunis
# Eritrea       101,000       Asmara

# %%
Health_final = Health_df.rename(columns = {"Rank": "Helath Care Rank",
                                           "Health_Care_Index": "Health Care Approval Rating"})
Health_final.head()
# Out:
#    Helath Care Rank      Country  Health Care Approval Rating
# 0                 1       Taiwan                        86.71
# 1                 2  South Korea                        81.97
# 2                 3        Japan                        81.14
# 3                 4      Denmark                        80.00
# 4                 5       France                        79.99

# %%
Health_final.set_index("Country", inplace=True)
Health_final.head()
# Out:
#              Helath Care Rank  Health Care Approval Rating
# Country
# Taiwan                      1                        86.71
# South Korea                 2                        81.97
# Japan                       3                        81.14
# Denmark                     4                        80.00
# France                      5                        79.99

# %%
merge1 = pd.merge(GDP_final,Rankings_final, on = ["Country"])
merge2 = pd.merge(merge1,Growth_final, on = ["Country"])
merge_final = pd.merge(merge2,Health_final, on = ["Country"])

merge_final.head()
# Out:
#                GDP Ranking         GDP  Ease of Doing Business Rank  \
# Country
# United States            1  21,427,700                            6
# China                    2  14,342,903                           78
# Japan                    3   5,081,770                           34
# Germany                  4   3,845,630                           20
# India                    5   2,875,142                          100
#
#                Starting a Business  Dealing with Construction Permits  \
# Country
# United States                   49                                 36
# China                           93                                172
# Japan                          106                                 50
# Germany                        113                                 24
# India                          156                                181
#
#                Getting Electricity  Registering Property  Getting Credit  \
# Country
# ...

# %%
Final = pd.merge(merge_final,Final_Merge, on = ["Country"])
Final.head()
# Out:
#          Country  GDP Ranking         GDP  Ease of Doing Business Rank  \
# 0  United States            1  21,427,700                            6
# 1          China            2  14,342,903                           78
# 2          Japan            3   5,081,770                           34
# 3        Germany            4   3,845,630                           20
# 4          India            5   2,875,142                          100
#
#    Starting a Business  Dealing with Construction Permits  \
# 0                   49                                 36
# 1                   93                                172
# 2                  106                                 50
# 3                  113                                 24
# 4                  156                                181
#
#    Getting Electricity  Registering Property  Getting Credit  \
# 0                   49                    37               2
# 1                   98                    41              68
# ...

# %%
Final.to_csv(r“Resources\Mongo_Data.csv”)

# %%
# Out:
#   File "<ipython-input-81-ade32c1563ef>", line 1
#     Final.to_csv(r“Resources\Mongo_Data.csv”)
#                            ^
# SyntaxError: invalid character in identifier
